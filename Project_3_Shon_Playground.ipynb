# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


df = pd.read_csv ("allusers.lcl.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    Class  User         X0         Y0         Z0         X1         Y1  \
# 0      0     0   0.000000   0.000000   0.000000   0.000000   0.000000
# 1      1     0  54.263880  71.466776 -64.807709  76.895635  42.462500
# 2      1     0  56.527558  72.266609 -61.935252  39.135978  82.538530
# 3      1     0  55.849928  72.469064 -62.562788  37.988804  82.631347
# 4      1     0  55.329647  71.707275 -63.688956  36.561863  81.868749
#
#           Z1         X2         Y2         Z2                X3  \
# 0   0.000000   0.000000   0.000000   0.000000                 0
# 1 -72.780545  36.621229  81.680557 -52.919272  85.2322638852917
# 2 -49.596509  79.223743  43.254091 -69.982489  87.4508729469625
# 3 -50.606259  78.451526  43.567403 -70.658489  86.8353875680762
# 4 -52.752784  86.320630  68.214645 -72.228461  61.5961571288978
#
#                  Y3                 Z3                X4                Y4  \
# 0                 0                  0                 0                 0
# ...

# %%
df.drop(0,inplace=True)
df.head()
# Out:
#    Class  User         X0         Y0         Z0         X1         Y1  \
# 1      1     0  54.263880  71.466776 -64.807709  76.895635  42.462500
# 2      1     0  56.527558  72.266609 -61.935252  39.135978  82.538530
# 3      1     0  55.849928  72.469064 -62.562788  37.988804  82.631347
# 4      1     0  55.329647  71.707275 -63.688956  36.561863  81.868749
# 5      1     0  55.142401  71.435607 -64.177303  36.175818  81.556874
#
#           Z1         X2         Y2         Z2                X3  \
# 1 -72.780545  36.621229  81.680557 -52.919272  85.2322638852917
# 2 -49.596509  79.223743  43.254091 -69.982489  87.4508729469625
# 3 -50.606259  78.451526  43.567403 -70.658489  86.8353875680762
# 4 -52.752784  86.320630  68.214645 -72.228461  61.5961571288978
# 5 -53.475747  76.986143  42.426849 -72.574743  86.3687480605765
#
#                  Y3                 Z3                X4                Y4  \
# 1  67.7492195028673   -73.684130041833  59.1885757027887  10.6789364098231
# ...

# %%
df = df.replace(to_replace="?", value='NaN')
df.head()
# Out:
#    Class  User         X0         Y0         Z0         X1         Y1  \
# 1      1     0  54.263880  71.466776 -64.807709  76.895635  42.462500
# 2      1     0  56.527558  72.266609 -61.935252  39.135978  82.538530
# 3      1     0  55.849928  72.469064 -62.562788  37.988804  82.631347
# 4      1     0  55.329647  71.707275 -63.688956  36.561863  81.868749
# 5      1     0  55.142401  71.435607 -64.177303  36.175818  81.556874
#
#           Z1         X2         Y2         Z2                X3  \
# 1 -72.780545  36.621229  81.680557 -52.919272  85.2322638852917
# 2 -49.596509  79.223743  43.254091 -69.982489  87.4508729469625
# 3 -50.606259  78.451526  43.567403 -70.658489  86.8353875680762
# 4 -52.752784  86.320630  68.214645 -72.228461  61.5961571288978
# 5 -53.475747  76.986143  42.426849 -72.574743  86.3687480605765
#
#                  Y3                 Z3                X4                Y4  \
# 1  67.7492195028673   -73.684130041833  59.1885757027887  10.6789364098231
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.describe()
# Out:
#               Class          User            X0            Y0            Z0  \
# count  78095.000000  78095.000000  78095.000000  78095.000000  78095.000000
# mean       2.983776      7.959229     50.346308     85.813150    -29.985096
# std        1.421152      4.697754     32.695886     40.203448     34.361971
# min        1.000000      0.000000   -108.552738    -98.233756   -126.770872
# 25%        2.000000      5.000000     29.295141     63.497746    -56.356593
# 50%        3.000000      9.000000     54.620245     86.526334    -30.864248
# 75%        4.000000     12.000000     72.488833    113.108673     -1.419462
# max        5.000000     14.000000    190.017835    169.175464    113.345119
#
#                  X1            Y1            Z1            X2            Y2  \
# count  78095.000000  78095.000000  78095.000000  78095.000000  78095.000000
# mean      49.595844     86.193751    -29.509579     48.612744     83.772387
# ...

# %%
from pandas.plotting import scatter_matrix

ax = scatter_matrix(df,figsize=(15, 10))

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
space = plt.figure().gca(projection='3d')
space.scatter(df.query('Class==1')['X0'], df.query('Class==1')['Y0'], df.query('Class==1')['Z0'])

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
ax = plt.axes(projection='3d')
ax.plot3D(df['X0'],df['Y0'],df['Z0'], 'gray')

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(df['X0'],df['Y0'],df['Z0'], 'Greens')

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(df['X0'],df['Y0'],df['Z0'], zdir='z', s=20, c='Green', depthshade=True)

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(df['X0'],df['Y0'],df['Z0'], zdir='z', s=20, c='Red', depthshade=True)
ax.scatter3D(df['X1'],df['Y1'],df['Z1'], zdir='z', s=20, c='Blue', depthshade=True)
ax.scatter3D(df['X2'],df['Y2'],df['Z2'], zdir='z', s=20, c='Green', depthshade=True)
ax.scatter3D(df['X3'],df['Y3'],df['Z3'], zdir='z', s=20, c='Orange', depthshade=True)
ax.scatter3D(df['X4'],df['Y4'],df['Z4'], zdir='z', s=20, c='Yellow', depthshade=True)
ax.scatter3D(df['X5'],df['Y5'],df['Z5'], zdir='z', s=20, c='Violet', depthshade=True)
ax.scatter3D(df['X6'],df['Y6'],df['Z6'], zdir='z', s=20, c='Gray', depthshade=True)
ax.scatter3D(df['X7'],df['Y7'],df['Z7'], zdir='z', s=20, c='Crimson', depthshade=True)
ax.scatter3D(df['X8'],df['Y8'],df['Z8'], zdir='z', s=20, c='Magenta', depthshade=True)
ax.scatter3D(df['X9'],df['Y9'],df['Z9'], zdir='z', s=20, c='Tan', depthshade=True)
ax.scatter3D(df['X10'],df['Y10'],df['Z10'], zdir='z', s=20, c='Pink', depthshade=True)
ax.scatter3D(df['X11'],df['Y11'],df['Z11'], zdir='z', s=20, c='Cyan', depthshade=True)
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000002F014C92F28> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Programs\Anaconda\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# D:\Programs\Anaconda\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# D:\Programs\Anaconda\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
# ...
